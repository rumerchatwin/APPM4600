# %%
x = [1, 2, 3]

# %%
3*x
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
import numpy as np

# %%
y = np.array([1,2,3])

# %%
3*y
# Out:
# array([3, 6, 9])

# %%
print('this is 3y', 3*y)
# Out:
# this is 3y [3 6 9]

# %%
import matplotlib.pyplot as plt

# %%
X = np.linspace(0, 2 * np.pi, 100)
Ya = np.sin(X)
Yb = np.cos(X)

# %%
plt.plot(X, Ya)
plt.plot(X, Yb)
plt.show()

# %%
X = np.linspace(0, 2 * np.pi, 100)
Ya = np.sin(X)
Yb = np.cos(X)
plt.plot(X, Ya)
plt.plot(X, Yb)
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')
